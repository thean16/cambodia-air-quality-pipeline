# %%
pip install requests pandas
# Out:
# Requirement already satisfied: requests in d:\anaconda\lib\site-packages (2.32.3)
# Requirement already satisfied: pandas in d:\anaconda\lib\site-packages (2.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda\lib\site-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\lib\site-packages (from requests) (2024.8.30)
# Requirement already satisfied: numpy>=1.26.0 in d:\anaconda\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\anaconda\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\anaconda\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in d:\anaconda\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import pandas as pd
import os
import time
from datetime import datetime

# NEW — saves inside your current VS Code project folder
import os
OUTPUT_DIR = os.path.join(os.getcwd(), "live_input")
print("Saving CSVs to:", OUTPUT_DIR)
INTERVAL   = 60  # seconds between each CSV

CITIES = [
    {"city": "Phnom Penh",    "lat": 11.5564, "lon": 104.9282},
    {"city": "Siem Reap",     "lat": 13.3671, "lon": 103.8448},
    {"city": "Battambang",    "lat": 13.1024, "lon": 103.1988},
    {"city": "Kampot",        "lat": 10.6108, "lon": 104.1812},
    {"city": "Sihanoukville", "lat": 10.6097, "lon": 103.5297},
]
# Out:
# Saving CSVs to: c:\Users\User\OneDrive\Desktop\AMS\Air Quality Analysis Pipeline\live_input

# %%
def fetch_one_city(city_info):
    url = "https://air-quality-api.open-meteo.com/v1/air-quality"
    params = {
        "latitude":  city_info["lat"],
        "longitude": city_info["lon"],
        "current":   "pm2_5,pm10,carbon_monoxide,nitrogen_dioxide,sulphur_dioxide,ozone,european_aqi",
        "timezone":  "Asia/Phnom_Penh",
    }
    try:
        res = requests.get(url, params=params, timeout=15)
        res.raise_for_status()           # crash if HTTP error
        current = res.json()["current"]

        return {
            "city":       city_info["city"],
            "latitude":   city_info["lat"],
            "longitude":  city_info["lon"],
            "datetime":   current.get("time"),
            "aqi":        current.get("european_aqi"),
            "pm25":       current.get("pm2_5"),
            "pm10":       current.get("pm10"),
            "co":         current.get("carbon_monoxide"),
            "no2":        current.get("nitrogen_dioxide"),
            "so2":        current.get("sulphur_dioxide"),
            "o3":         current.get("ozone"),
            "created_at": datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
        }

    except requests.exceptions.Timeout:
        print(f"  [TIMEOUT]  {city_info['city']}")
    except requests.exceptions.ConnectionError:
        print(f"  [NO INTERNET]  {city_info['city']}")
    except Exception as e:
        print(f"  [ERROR]  {city_info['city']} — {e}")

    return None   # skip this city if any error

# %%
os.makedirs(OUTPUT_DIR, exist_ok=True)

# ONE fixed filename — never changes
COMBINED_FILE = os.path.join(OUTPUT_DIR, "air_quality_combined.csv")

while True:
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    print(f"\n[{timestamp}] Fetching data...")

    rows = []
    for city in CITIES:
        result = fetch_one_city(city)
        if result:
            rows.append(result)
            print(f"  ✓ {city['city']}  AQI={result['aqi']}  PM2.5={result['pm25']}")

    if rows:
        new_df = pd.DataFrame(rows)

        # If file exists → append, if not → create with header
        if os.path.exists(COMBINED_FILE):
            new_df.to_csv(COMBINED_FILE, mode="a", index=False, header=False)
            print(f"  → Appended {len(rows)} rows to air_quality_combined.csv")
        else:
            new_df.to_csv(COMBINED_FILE, mode="w", index=False, header=True)
            print(f"  → Created air_quality_combined.csv")

        # Show current total rows
        total = pd.read_csv(COMBINED_FILE).shape[0]
        print(f"  → Total rows in file: {total}")

    print(f"  Waiting {INTERVAL}s...")
    time.sleep(INTERVAL)
# Out:
# [20260613_015736] Fetching data...
#   ✓ Phnom Penh  AQI=62  PM2.5=30.3
#   ✓ Siem Reap  AQI=16  PM2.5=6.3
#   ✓ Battambang  AQI=25  PM2.5=15.1
#   ✓ Kampot  AQI=20  PM2.5=15.7
#   ✓ Sihanoukville  AQI=16  PM2.5=11.9
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 30
#   Waiting 60s...
#
# [20260613_015842] Fetching data...
#   ✓ Phnom Penh  AQI=62  PM2.5=30.3
#   ✓ Siem Reap  AQI=16  PM2.5=6.3
#   ✓ Battambang  AQI=25  PM2.5=15.1
#   ✓ Kampot  AQI=20  PM2.5=15.7
#   ✓ Sihanoukville  AQI=16  PM2.5=11.9
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 35
#   Waiting 60s...
#
# [20260613_015948] Fetching data...
#   ✓ Phnom Penh  AQI=62  PM2.5=30.3
#   ✓ Siem Reap  AQI=16  PM2.5=6.3
#   ✓ Battambang  AQI=25  PM2.5=15.1
#   ✓ Kampot  AQI=20  PM2.5=15.7
#   ✓ Sihanoukville  AQI=16  PM2.5=11.9
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 40
#   Waiting 60s...
#
# [20260613_020053] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=29.8
#   ✓ Siem Reap  AQI=15  PM2.5=6.3
#   ✓ Battambang  AQI=25  PM2.5=16.1
#   ✓ Kampot  AQI=20  PM2.5=15.5
#   ✓ Sihanoukville  AQI=16  PM2.5=13.3
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 45
#   Waiting 60s...
#
# [20260613_020159] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=29.8
#   ✓ Siem Reap  AQI=15  PM2.5=6.3
#   ✓ Battambang  AQI=25  PM2.5=16.1
#   ✓ Kampot  AQI=20  PM2.5=15.5
#   ✓ Sihanoukville  AQI=16  PM2.5=13.3
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 50
#   Waiting 60s...
#
# [20260613_020304] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=29.8
#   ✓ Siem Reap  AQI=15  PM2.5=6.3
#   ✓ Battambang  AQI=25  PM2.5=16.1
#   ✓ Kampot  AQI=20  PM2.5=15.5
#   ✓ Sihanoukville  AQI=16  PM2.5=13.3
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 55
#   Waiting 60s...
#
# [20260613_020412] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=29.8
#   ✓ Siem Reap  AQI=15  PM2.5=6.3
#   ✓ Battambang  AQI=25  PM2.5=16.1
#   ✓ Kampot  AQI=20  PM2.5=15.5
#   ✓ Sihanoukville  AQI=16  PM2.5=13.3
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 60
#   Waiting 60s...
#
# [20260613_020517] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=29.8
#   ✓ Siem Reap  AQI=15  PM2.5=6.3
#   ✓ Battambang  AQI=25  PM2.5=16.1
#   ✓ Kampot  AQI=20  PM2.5=15.5
#   ✓ Sihanoukville  AQI=16  PM2.5=13.3
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 65
#   Waiting 60s...
#
# [20260613_020623] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=29.8
#   ✓ Siem Reap  AQI=15  PM2.5=6.3
#   ✓ Battambang  AQI=25  PM2.5=16.1
#   ✓ Kampot  AQI=20  PM2.5=15.5
#   ✓ Sihanoukville  AQI=16  PM2.5=13.3
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 70
#   Waiting 60s...
#
# [20260613_020729] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=29.8
#   ✓ Siem Reap  AQI=15  PM2.5=6.3
#   ✓ Battambang  AQI=25  PM2.5=16.1
#   ✓ Kampot  AQI=20  PM2.5=15.5
#   ✓ Sihanoukville  AQI=16  PM2.5=13.3
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 75
#   Waiting 60s...
#
# [20260613_020834] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=29.8
#   ✓ Siem Reap  AQI=15  PM2.5=6.3
#   ✓ Battambang  AQI=25  PM2.5=16.1
#   ✓ Kampot  AQI=20  PM2.5=15.5
#   ✓ Sihanoukville  AQI=16  PM2.5=13.3
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 80
#   Waiting 60s...
#
# [20260613_020940] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=29.8
#   ✓ Siem Reap  AQI=15  PM2.5=6.3
#   ✓ Battambang  AQI=25  PM2.5=16.1
#   ✓ Kampot  AQI=20  PM2.5=15.5
#   ✓ Sihanoukville  AQI=16  PM2.5=13.3
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 85
#   Waiting 60s...
#
# [20260613_021046] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=29.8
#   ✓ Siem Reap  AQI=15  PM2.5=6.3
#   ✓ Battambang  AQI=25  PM2.5=16.1
#   ✓ Kampot  AQI=20  PM2.5=15.5
#   ✓ Sihanoukville  AQI=16  PM2.5=13.3
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 90
#   Waiting 60s...
#
# [20260613_021150] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=29.8
#   ✓ Siem Reap  AQI=15  PM2.5=6.3
#   ✓ Battambang  AQI=25  PM2.5=16.1
#   ✓ Kampot  AQI=20  PM2.5=15.5
#   ✓ Sihanoukville  AQI=16  PM2.5=13.3
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 95
#   Waiting 60s...
#
# [20260613_021256] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=29.8
#   ✓ Siem Reap  AQI=15  PM2.5=6.3
#   ✓ Battambang  AQI=25  PM2.5=16.1
#   ✓ Kampot  AQI=20  PM2.5=15.5
#   ✓ Sihanoukville  AQI=16  PM2.5=13.3
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 100
#   Waiting 60s...
#
# [20260613_021403] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=29.8
#   ✓ Siem Reap  AQI=15  PM2.5=6.3
#   ✓ Battambang  AQI=25  PM2.5=16.1
#   ✓ Kampot  AQI=20  PM2.5=15.5
#   ✓ Sihanoukville  AQI=16  PM2.5=13.3
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 105
#   Waiting 60s...
#
# [20260613_021509] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=29.8
#   ✓ Siem Reap  AQI=15  PM2.5=6.3
#   ✓ Battambang  AQI=25  PM2.5=16.1
#   ✓ Kampot  AQI=20  PM2.5=15.5
#   ✓ Sihanoukville  AQI=16  PM2.5=13.3
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 110
#   Waiting 60s...
#
# [20260613_021615] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=29.8
#   ✓ Siem Reap  AQI=15  PM2.5=6.3
#   ✓ Battambang  AQI=25  PM2.5=16.1
#   ✓ Kampot  AQI=20  PM2.5=15.5
#   ✓ Sihanoukville  AQI=16  PM2.5=13.3
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 115
#   Waiting 60s...
#
# [20260613_021721] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=29.8
#   ✓ Siem Reap  AQI=15  PM2.5=6.3
#   ✓ Battambang  AQI=25  PM2.5=16.1
#   ✓ Kampot  AQI=20  PM2.5=15.5
#   ✓ Sihanoukville  AQI=16  PM2.5=13.3
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 120
#   Waiting 60s...
#
# [20260613_021828] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=29.8
#   ✓ Siem Reap  AQI=15  PM2.5=6.3
#   ✓ Battambang  AQI=25  PM2.5=16.1
#   ✓ Kampot  AQI=20  PM2.5=15.5
#   ✓ Sihanoukville  AQI=16  PM2.5=13.3
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 125
#   Waiting 60s...
#
# [20260613_021935] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=29.8
#   ✓ Siem Reap  AQI=15  PM2.5=6.3
#   ✓ Battambang  AQI=25  PM2.5=16.1
#   ✓ Kampot  AQI=20  PM2.5=15.5
#   ✓ Sihanoukville  AQI=16  PM2.5=13.3
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 130
#   Waiting 60s...
#
# [20260613_022041] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=29.8
#   ✓ Siem Reap  AQI=15  PM2.5=6.3
#   ✓ Battambang  AQI=25  PM2.5=16.1
#   ✓ Kampot  AQI=20  PM2.5=15.5
#   ✓ Sihanoukville  AQI=16  PM2.5=13.3
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 135
#   Waiting 60s...
#
# [20260613_022147] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=29.8
#   ✓ Siem Reap  AQI=15  PM2.5=6.3
#   ✓ Battambang  AQI=25  PM2.5=16.1
#   ✓ Kampot  AQI=20  PM2.5=15.5
#   ✓ Sihanoukville  AQI=16  PM2.5=13.3
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 140
#   Waiting 60s...
#
# [20260613_022252] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=29.8
#   ✓ Siem Reap  AQI=15  PM2.5=6.3
#   ✓ Battambang  AQI=25  PM2.5=16.1
#   ✓ Kampot  AQI=20  PM2.5=15.5
#   ✓ Sihanoukville  AQI=16  PM2.5=13.3
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 145
#   Waiting 60s...
#
# [20260613_022358] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=29.8
#   ✓ Siem Reap  AQI=15  PM2.5=6.3
#   ✓ Battambang  AQI=25  PM2.5=16.1
#   ✓ Kampot  AQI=20  PM2.5=15.5
#   ✓ Sihanoukville  AQI=16  PM2.5=13.3
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 150
#   Waiting 60s...
#
# [20260613_022504] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=29.8
#   ✓ Siem Reap  AQI=15  PM2.5=6.3
#   ✓ Battambang  AQI=25  PM2.5=16.1
#   ✓ Kampot  AQI=20  PM2.5=15.5
#   ✓ Sihanoukville  AQI=16  PM2.5=13.3
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 155
#   Waiting 60s...
#
# [20260613_022610] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=29.8
#   ✓ Siem Reap  AQI=15  PM2.5=6.3
#   ✓ Battambang  AQI=25  PM2.5=16.1
#   ✓ Kampot  AQI=20  PM2.5=15.5
#   ✓ Sihanoukville  AQI=16  PM2.5=13.3
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 160
#   Waiting 60s...
#
# [20260613_022717] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=29.8
#   ✓ Siem Reap  AQI=15  PM2.5=6.3
#   ✓ Battambang  AQI=25  PM2.5=16.1
#   ✓ Kampot  AQI=20  PM2.5=15.5
#   ✓ Sihanoukville  AQI=16  PM2.5=13.3
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 165
#   Waiting 60s...
#
# [20260613_022822] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=29.8
#   ✓ Siem Reap  AQI=15  PM2.5=6.3
#   ✓ Battambang  AQI=25  PM2.5=16.1
#   ✓ Kampot  AQI=20  PM2.5=15.5
#   ✓ Sihanoukville  AQI=16  PM2.5=13.3
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 170
#   Waiting 60s...
#
# [20260613_022928] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=29.8
#   ✓ Siem Reap  AQI=15  PM2.5=6.3
#   ✓ Battambang  AQI=25  PM2.5=16.1
#   ✓ Kampot  AQI=20  PM2.5=15.5
#   ✓ Sihanoukville  AQI=16  PM2.5=13.3
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 175
#   Waiting 60s...
#
# [20260613_023033] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=29.8
#   ✓ Siem Reap  AQI=15  PM2.5=6.3
#   ✓ Battambang  AQI=25  PM2.5=16.1
#   ✓ Kampot  AQI=20  PM2.5=15.5
#   ✓ Sihanoukville  AQI=16  PM2.5=13.3
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 180
#   Waiting 60s...
#
# [20260613_023138] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=29.8
#   ✓ Siem Reap  AQI=15  PM2.5=6.3
#   ✓ Battambang  AQI=25  PM2.5=16.1
#   ✓ Kampot  AQI=20  PM2.5=15.5
#   ✓ Sihanoukville  AQI=16  PM2.5=13.3
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 185
#   Waiting 60s...
#
# [20260613_023244] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=29.8
#   ✓ Siem Reap  AQI=15  PM2.5=6.3
#   ✓ Battambang  AQI=25  PM2.5=16.1
#   ✓ Kampot  AQI=20  PM2.5=15.5
#   ✓ Sihanoukville  AQI=16  PM2.5=13.3
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 190
#   Waiting 60s...
#
# [20260613_023350] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=29.8
#   ✓ Siem Reap  AQI=15  PM2.5=6.3
#   ✓ Battambang  AQI=25  PM2.5=16.1
#   ✓ Kampot  AQI=20  PM2.5=15.5
#   ✓ Sihanoukville  AQI=16  PM2.5=13.3
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 195
#   Waiting 60s...
#
# [20260613_023458] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=29.8
#   ✓ Siem Reap  AQI=15  PM2.5=6.3
#   ✓ Battambang  AQI=25  PM2.5=16.1
#   ✓ Kampot  AQI=20  PM2.5=15.5
#   ✓ Sihanoukville  AQI=16  PM2.5=13.3
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 200
#   Waiting 60s...
#
# [20260613_023604] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=29.8
#   ✓ Siem Reap  AQI=15  PM2.5=6.3
#   ✓ Battambang  AQI=25  PM2.5=16.1
#   ✓ Kampot  AQI=20  PM2.5=15.5
#   ✓ Sihanoukville  AQI=16  PM2.5=13.3
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 205
#   Waiting 60s...
#
# [20260613_023710] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=29.8
#   ✓ Siem Reap  AQI=15  PM2.5=6.3
#   ✓ Battambang  AQI=25  PM2.5=16.1
#   ✓ Kampot  AQI=20  PM2.5=15.5
#   ✓ Sihanoukville  AQI=16  PM2.5=13.3
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 210
#   Waiting 60s...
#
# [20260613_023816] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=29.8
#   ✓ Siem Reap  AQI=15  PM2.5=6.3
#   ✓ Battambang  AQI=25  PM2.5=16.1
#   ✓ Kampot  AQI=20  PM2.5=15.5
#   ✓ Sihanoukville  AQI=16  PM2.5=13.3
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 215
#   Waiting 60s...
#
# [20260613_023923] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=29.8
#   ✓ Siem Reap  AQI=15  PM2.5=6.3
#   ✓ Battambang  AQI=25  PM2.5=16.1
#   ✓ Kampot  AQI=20  PM2.5=15.5
#   ✓ Sihanoukville  AQI=16  PM2.5=13.3
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 220
#   Waiting 60s...
#
# [20260613_024028] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=29.8
#   ✓ Siem Reap  AQI=15  PM2.5=6.3
#   ✓ Battambang  AQI=25  PM2.5=16.1
#   ✓ Kampot  AQI=20  PM2.5=15.5
#   ✓ Sihanoukville  AQI=16  PM2.5=13.3
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 225
#   Waiting 60s...
#
# [20260613_024133] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=29.8
#   ✓ Siem Reap  AQI=15  PM2.5=6.3
#   ✓ Battambang  AQI=25  PM2.5=16.1
#   ✓ Kampot  AQI=20  PM2.5=15.5
#   ✓ Sihanoukville  AQI=16  PM2.5=13.3
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 230
#   Waiting 60s...
#
# [20260613_024238] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=29.8
#   ✓ Siem Reap  AQI=15  PM2.5=6.3
#   ✓ Battambang  AQI=25  PM2.5=16.1
#   ✓ Kampot  AQI=20  PM2.5=15.5
#   ✓ Sihanoukville  AQI=16  PM2.5=13.3
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 235
#   Waiting 60s...
#
# [20260613_024344] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=29.8
#   ✓ Siem Reap  AQI=15  PM2.5=6.3
#   ✓ Battambang  AQI=25  PM2.5=16.1
#   ✓ Kampot  AQI=20  PM2.5=15.5
#   ✓ Sihanoukville  AQI=16  PM2.5=13.3
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 240
#   Waiting 60s...
#
# [20260613_024450] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=29.8
#   ✓ Siem Reap  AQI=15  PM2.5=6.3
#   ✓ Battambang  AQI=25  PM2.5=16.1
#   ✓ Kampot  AQI=20  PM2.5=15.5
#   ✓ Sihanoukville  AQI=16  PM2.5=13.3
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 245
#   Waiting 60s...
#
# [20260613_024557] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=29.8
#   ✓ Siem Reap  AQI=15  PM2.5=6.3
#   ✓ Battambang  AQI=25  PM2.5=16.1
#   ✓ Kampot  AQI=20  PM2.5=15.5
#   ✓ Sihanoukville  AQI=16  PM2.5=13.3
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 250
#   Waiting 60s...
#
# [20260613_024702] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=29.8
#   ✓ Siem Reap  AQI=15  PM2.5=6.3
#   ✓ Battambang  AQI=25  PM2.5=16.1
#   ✓ Kampot  AQI=20  PM2.5=15.5
#   ✓ Sihanoukville  AQI=16  PM2.5=13.3
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 255
#   Waiting 60s...
#
# [20260613_024808] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=29.8
#   ✓ Siem Reap  AQI=15  PM2.5=6.3
#   ✓ Battambang  AQI=25  PM2.5=16.1
#   ✓ Kampot  AQI=20  PM2.5=15.5
#   ✓ Sihanoukville  AQI=16  PM2.5=13.3
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 260
#   Waiting 60s...
#
# [20260613_024912] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=29.8
#   ✓ Siem Reap  AQI=15  PM2.5=6.3
#   ✓ Battambang  AQI=25  PM2.5=16.1
#   ✓ Kampot  AQI=20  PM2.5=15.5
#   ✓ Sihanoukville  AQI=16  PM2.5=13.3
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 265
#   Waiting 60s...
#
# [20260613_025018] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=29.8
#   ✓ Siem Reap  AQI=15  PM2.5=6.3
#   ✓ Battambang  AQI=25  PM2.5=16.1
#   ✓ Kampot  AQI=20  PM2.5=15.5
#   ✓ Sihanoukville  AQI=16  PM2.5=13.3
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 270
#   Waiting 60s...
#
# [20260613_025124] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=29.8
#   ✓ Siem Reap  AQI=15  PM2.5=6.3
#   ✓ Battambang  AQI=25  PM2.5=16.1
#   ✓ Kampot  AQI=20  PM2.5=15.5
#   ✓ Sihanoukville  AQI=16  PM2.5=13.3
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 275
#   Waiting 60s...
#
# [20260613_025231] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=29.8
#   ✓ Siem Reap  AQI=15  PM2.5=6.3
#   ✓ Battambang  AQI=25  PM2.5=16.1
#   ✓ Kampot  AQI=20  PM2.5=15.5
#   ✓ Sihanoukville  AQI=16  PM2.5=13.3
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 280
#   Waiting 60s...
#
# [20260613_025337] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=29.8
#   ✓ Siem Reap  AQI=15  PM2.5=6.3
#   ✓ Battambang  AQI=25  PM2.5=16.1
#   ✓ Kampot  AQI=20  PM2.5=15.5
#   ✓ Sihanoukville  AQI=16  PM2.5=13.3
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 285
#   Waiting 60s...
#
# [20260613_025443] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=29.8
#   ✓ Siem Reap  AQI=15  PM2.5=6.3
#   ✓ Battambang  AQI=25  PM2.5=16.1
#   ✓ Kampot  AQI=20  PM2.5=15.5
#   ✓ Sihanoukville  AQI=16  PM2.5=13.3
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 290
#   Waiting 60s...
#
# [20260613_025550] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=29.8
#   ✓ Siem Reap  AQI=15  PM2.5=6.3
#   ✓ Battambang  AQI=25  PM2.5=16.1
#   ✓ Kampot  AQI=20  PM2.5=15.5
#   ✓ Sihanoukville  AQI=16  PM2.5=13.3
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 295
#   Waiting 60s...
#
# [20260613_025657] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=29.8
#   ✓ Siem Reap  AQI=15  PM2.5=6.3
#   ✓ Battambang  AQI=25  PM2.5=16.1
#   ✓ Kampot  AQI=20  PM2.5=15.5
#   ✓ Sihanoukville  AQI=16  PM2.5=13.3
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 300
#   Waiting 60s...
#
# [20260613_025803] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=29.8
#   ✓ Siem Reap  AQI=15  PM2.5=6.3
#   ✓ Battambang  AQI=25  PM2.5=16.1
#   ✓ Kampot  AQI=20  PM2.5=15.5
#   ✓ Sihanoukville  AQI=16  PM2.5=13.3
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 305
#   Waiting 60s...
#
# [20260613_025909] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=29.8
#   ✓ Siem Reap  AQI=15  PM2.5=6.3
#   ✓ Battambang  AQI=25  PM2.5=16.1
#   ✓ Kampot  AQI=20  PM2.5=15.5
#   ✓ Sihanoukville  AQI=16  PM2.5=13.3
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 310
#   Waiting 60s...
#
# [20260613_030013] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=31.0
#   ✓ Siem Reap  AQI=14  PM2.5=6.4
#   ✓ Battambang  AQI=25  PM2.5=17.3
#   ✓ Kampot  AQI=21  PM2.5=15.3
#   ✓ Sihanoukville  AQI=16  PM2.5=13.6
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 315
#   Waiting 60s...
#
# [20260613_030120] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=31.0
#   ✓ Siem Reap  AQI=14  PM2.5=6.4
#   ✓ Battambang  AQI=25  PM2.5=17.3
#   ✓ Kampot  AQI=21  PM2.5=15.3
#   ✓ Sihanoukville  AQI=16  PM2.5=13.6
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 320
#   Waiting 60s...
#
# [20260613_030227] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=31.0
#   ✓ Siem Reap  AQI=14  PM2.5=6.4
#   ✓ Battambang  AQI=25  PM2.5=17.3
#   ✓ Kampot  AQI=21  PM2.5=15.3
#   ✓ Sihanoukville  AQI=16  PM2.5=13.6
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 325
#   Waiting 60s...
#
# [20260613_030333] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=31.0
#   ✓ Siem Reap  AQI=14  PM2.5=6.4
#   ✓ Battambang  AQI=25  PM2.5=17.3
#   ✓ Kampot  AQI=21  PM2.5=15.3
#   ✓ Sihanoukville  AQI=16  PM2.5=13.6
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 330
#   Waiting 60s...
#
# [20260613_030438] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=31.0
#   ✓ Siem Reap  AQI=14  PM2.5=6.4
#   ✓ Battambang  AQI=25  PM2.5=17.3
#   ✓ Kampot  AQI=21  PM2.5=15.3
#   ✓ Sihanoukville  AQI=16  PM2.5=13.6
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 335
#   Waiting 60s...
#
# [20260613_030542] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=31.0
#   ✓ Siem Reap  AQI=14  PM2.5=6.4
#   ✓ Battambang  AQI=25  PM2.5=17.3
#   ✓ Kampot  AQI=21  PM2.5=15.3
#   ✓ Sihanoukville  AQI=16  PM2.5=13.6
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 340
#   Waiting 60s...
#
# [20260613_030648] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=31.0
#   ✓ Siem Reap  AQI=14  PM2.5=6.4
#   ✓ Battambang  AQI=25  PM2.5=17.3
#   ✓ Kampot  AQI=21  PM2.5=15.3
#   ✓ Sihanoukville  AQI=16  PM2.5=13.6
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 345
#   Waiting 60s...
#
# [20260613_030752] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=31.0
#   ✓ Siem Reap  AQI=14  PM2.5=6.4
#   ✓ Battambang  AQI=25  PM2.5=17.3
#   ✓ Kampot  AQI=21  PM2.5=15.3
#   ✓ Sihanoukville  AQI=16  PM2.5=13.6
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 350
#   Waiting 60s...
#
# [20260613_030856] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=31.0
#   ✓ Siem Reap  AQI=14  PM2.5=6.4
#   ✓ Battambang  AQI=25  PM2.5=17.3
#   ✓ Kampot  AQI=21  PM2.5=15.3
#   ✓ Sihanoukville  AQI=16  PM2.5=13.6
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 355
#   Waiting 60s...
#
# [20260613_031000] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=31.0
#   ✓ Siem Reap  AQI=14  PM2.5=6.4
#   ✓ Battambang  AQI=25  PM2.5=17.3
#   ✓ Kampot  AQI=21  PM2.5=15.3
#   ✓ Sihanoukville  AQI=16  PM2.5=13.6
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 360
#   Waiting 60s...
#
# [20260613_031104] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=31.0
#   ✓ Siem Reap  AQI=14  PM2.5=6.4
#   ✓ Battambang  AQI=25  PM2.5=17.3
#   ✓ Kampot  AQI=21  PM2.5=15.3
#   ✓ Sihanoukville  AQI=16  PM2.5=13.6
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 365
#   Waiting 60s...
#
# [20260613_031208] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=31.0
#   ✓ Siem Reap  AQI=14  PM2.5=6.4
#   ✓ Battambang  AQI=25  PM2.5=17.3
#   ✓ Kampot  AQI=21  PM2.5=15.3
#   ✓ Sihanoukville  AQI=16  PM2.5=13.6
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 370
#   Waiting 60s...
#
# [20260613_031312] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=31.0
#   ✓ Siem Reap  AQI=14  PM2.5=6.4
#   ✓ Battambang  AQI=25  PM2.5=17.3
#   ✓ Kampot  AQI=21  PM2.5=15.3
#   ✓ Sihanoukville  AQI=16  PM2.5=13.6
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 375
#   Waiting 60s...
#
# [20260613_031417] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=31.0
#   ✓ Siem Reap  AQI=14  PM2.5=6.4
#   ✓ Battambang  AQI=25  PM2.5=17.3
#   ✓ Kampot  AQI=21  PM2.5=15.3
#   ✓ Sihanoukville  AQI=16  PM2.5=13.6
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 380
#   Waiting 60s...
#
# [20260613_031521] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=31.0
#   ✓ Siem Reap  AQI=14  PM2.5=6.4
#   ✓ Battambang  AQI=25  PM2.5=17.3
#   ✓ Kampot  AQI=21  PM2.5=15.3
#   ✓ Sihanoukville  AQI=16  PM2.5=13.6
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 385
#   Waiting 60s...
#
# [20260613_031626] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=31.0
#   ✓ Siem Reap  AQI=14  PM2.5=6.4
#   ✓ Battambang  AQI=25  PM2.5=17.3
#   ✓ Kampot  AQI=21  PM2.5=15.3
#   ✓ Sihanoukville  AQI=16  PM2.5=13.6
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 390
#   Waiting 60s...
#
# [20260613_031730] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=31.0
#   ✓ Siem Reap  AQI=14  PM2.5=6.4
#   ✓ Battambang  AQI=25  PM2.5=17.3
#   ✓ Kampot  AQI=21  PM2.5=15.3
#   ✓ Sihanoukville  AQI=16  PM2.5=13.6
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 395
#   Waiting 60s...
#
# [20260613_031834] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=31.0
#   ✓ Siem Reap  AQI=14  PM2.5=6.4
#   ✓ Battambang  AQI=25  PM2.5=17.3
#   ✓ Kampot  AQI=21  PM2.5=15.3
#   ✓ Sihanoukville  AQI=16  PM2.5=13.6
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 400
#   Waiting 60s...
#
# [20260613_031939] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=31.0
#   ✓ Siem Reap  AQI=14  PM2.5=6.4
#   ✓ Battambang  AQI=25  PM2.5=17.3
#   ✓ Kampot  AQI=21  PM2.5=15.3
#   ✓ Sihanoukville  AQI=16  PM2.5=13.6
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 405
#   Waiting 60s...
#
# [20260613_032043] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=31.0
#   ✓ Siem Reap  AQI=14  PM2.5=6.4
#   ✓ Battambang  AQI=25  PM2.5=17.3
#   ✓ Kampot  AQI=21  PM2.5=15.3
#   ✓ Sihanoukville  AQI=16  PM2.5=13.6
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 410
#   Waiting 60s...
#
# [20260613_032147] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=31.0
#   ✓ Siem Reap  AQI=14  PM2.5=6.4
#   ✓ Battambang  AQI=25  PM2.5=17.3
#   ✓ Kampot  AQI=21  PM2.5=15.3
#   ✓ Sihanoukville  AQI=16  PM2.5=13.6
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 415
#   Waiting 60s...
#
# [20260613_032251] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=31.0
#   ✓ Siem Reap  AQI=14  PM2.5=6.4
#   ✓ Battambang  AQI=25  PM2.5=17.3
#   ✓ Kampot  AQI=21  PM2.5=15.3
#   ✓ Sihanoukville  AQI=16  PM2.5=13.6
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 420
#   Waiting 60s...
#
# [20260613_032356] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=31.0
#   ✓ Siem Reap  AQI=14  PM2.5=6.4
#   ✓ Battambang  AQI=25  PM2.5=17.3
#   ✓ Kampot  AQI=21  PM2.5=15.3
#   ✓ Sihanoukville  AQI=16  PM2.5=13.6
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 425
#   Waiting 60s...
#
# [20260613_032500] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=31.0
#   ✓ Siem Reap  AQI=14  PM2.5=6.4
#   ✓ Battambang  AQI=25  PM2.5=17.3
#   ✓ Kampot  AQI=21  PM2.5=15.3
#   ✓ Sihanoukville  AQI=16  PM2.5=13.6
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 430
#   Waiting 60s...
#
# [20260613_032604] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=31.0
#   ✓ Siem Reap  AQI=14  PM2.5=6.4
#   ✓ Battambang  AQI=25  PM2.5=17.3
#   ✓ Kampot  AQI=21  PM2.5=15.3
#   ✓ Sihanoukville  AQI=16  PM2.5=13.6
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 435
#   Waiting 60s...
#
# [20260613_032708] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=31.0
#   ✓ Siem Reap  AQI=14  PM2.5=6.4
#   ✓ Battambang  AQI=25  PM2.5=17.3
#   ✓ Kampot  AQI=21  PM2.5=15.3
#   ✓ Sihanoukville  AQI=16  PM2.5=13.6
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 440
#   Waiting 60s...
#
# [20260613_032812] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=31.0
#   ✓ Siem Reap  AQI=14  PM2.5=6.4
#   ✓ Battambang  AQI=25  PM2.5=17.3
#   ✓ Kampot  AQI=21  PM2.5=15.3
#   ✓ Sihanoukville  AQI=16  PM2.5=13.6
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 445
#   Waiting 60s...
#
# [20260613_032931] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=31.0
#   ✓ Siem Reap  AQI=14  PM2.5=6.4
#   ✓ Battambang  AQI=25  PM2.5=17.3
#   ✓ Kampot  AQI=21  PM2.5=15.3
#   ✓ Sihanoukville  AQI=16  PM2.5=13.6
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 450
#   Waiting 60s...
#
# [20260613_033035] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=31.0
#   ✓ Siem Reap  AQI=14  PM2.5=6.4
#   ✓ Battambang  AQI=25  PM2.5=17.3
#   ✓ Kampot  AQI=21  PM2.5=15.3
#   ✓ Sihanoukville  AQI=16  PM2.5=13.6
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 455
#   Waiting 60s...
#
# [20260613_033139] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=31.0
#   ✓ Siem Reap  AQI=14  PM2.5=6.4
#   ✓ Battambang  AQI=25  PM2.5=17.3
#   ✓ Kampot  AQI=21  PM2.5=15.3
#   ✓ Sihanoukville  AQI=16  PM2.5=13.6
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 460
#   Waiting 60s...
#
# [20260613_033244] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=31.0
#   ✓ Siem Reap  AQI=14  PM2.5=6.4
#   ✓ Battambang  AQI=25  PM2.5=17.3
#   ✓ Kampot  AQI=21  PM2.5=15.3
#   ✓ Sihanoukville  AQI=16  PM2.5=13.6
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 465
#   Waiting 60s...
#
# [20260613_033348] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=31.0
#   ✓ Siem Reap  AQI=14  PM2.5=6.4
#   ✓ Battambang  AQI=25  PM2.5=17.3
#   ✓ Kampot  AQI=21  PM2.5=15.3
#   ✓ Sihanoukville  AQI=16  PM2.5=13.6
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 470
#   Waiting 60s...
#
# [20260613_033452] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=31.0
#   ✓ Siem Reap  AQI=14  PM2.5=6.4
#   ✓ Battambang  AQI=25  PM2.5=17.3
#   ✓ Kampot  AQI=21  PM2.5=15.3
#   ✓ Sihanoukville  AQI=16  PM2.5=13.6
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 475
#   Waiting 60s...
#
# [20260613_033556] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=31.0
#   ✓ Siem Reap  AQI=14  PM2.5=6.4
#   ✓ Battambang  AQI=25  PM2.5=17.3
#   ✓ Kampot  AQI=21  PM2.5=15.3
#   ✓ Sihanoukville  AQI=16  PM2.5=13.6
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 480
#   Waiting 60s...
#
# [20260613_033700] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=31.0
#   ✓ Siem Reap  AQI=14  PM2.5=6.4
#   ✓ Battambang  AQI=25  PM2.5=17.3
#   ✓ Kampot  AQI=21  PM2.5=15.3
#   ✓ Sihanoukville  AQI=16  PM2.5=13.6
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 485
#   Waiting 60s...
#
# [20260613_033804] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=31.0
#   ✓ Siem Reap  AQI=14  PM2.5=6.4
#   ✓ Battambang  AQI=25  PM2.5=17.3
#   ✓ Kampot  AQI=21  PM2.5=15.3
#   ✓ Sihanoukville  AQI=16  PM2.5=13.6
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 490
#   Waiting 60s...
#
# [20260613_033908] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=31.0
#   ✓ Siem Reap  AQI=14  PM2.5=6.4
#   ✓ Battambang  AQI=25  PM2.5=17.3
#   ✓ Kampot  AQI=21  PM2.5=15.3
#   ✓ Sihanoukville  AQI=16  PM2.5=13.6
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 495
#   Waiting 60s...
#
# [20260613_034013] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=31.0
#   ✓ Siem Reap  AQI=14  PM2.5=6.4
#   ✓ Battambang  AQI=25  PM2.5=17.3
#   ✓ Kampot  AQI=21  PM2.5=15.3
#   ✓ Sihanoukville  AQI=16  PM2.5=13.6
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 500
#   Waiting 60s...
#
# [20260613_034116] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=31.0
#   ✓ Siem Reap  AQI=14  PM2.5=6.4
#   ✓ Battambang  AQI=25  PM2.5=17.3
#   ✓ Kampot  AQI=21  PM2.5=15.3
#   ✓ Sihanoukville  AQI=16  PM2.5=13.6
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 505
#   Waiting 60s...
#
# [20260613_034220] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=31.0
#   ✓ Siem Reap  AQI=14  PM2.5=6.4
#   ✓ Battambang  AQI=25  PM2.5=17.3
#   ✓ Kampot  AQI=21  PM2.5=15.3
#   ✓ Sihanoukville  AQI=16  PM2.5=13.6
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 510
#   Waiting 60s...
#
# [20260613_034325] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=31.0
#   ✓ Siem Reap  AQI=14  PM2.5=6.4
#   ✓ Battambang  AQI=25  PM2.5=17.3
#   ✓ Kampot  AQI=21  PM2.5=15.3
#   ✓ Sihanoukville  AQI=16  PM2.5=13.6
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 515
#   Waiting 60s...
#
# [20260613_034429] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=31.0
#   ✓ Siem Reap  AQI=14  PM2.5=6.4
#   ✓ Battambang  AQI=25  PM2.5=17.3
#   ✓ Kampot  AQI=21  PM2.5=15.3
#   ✓ Sihanoukville  AQI=16  PM2.5=13.6
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 520
#   Waiting 60s...
#
# [20260613_034534] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=31.0
#   ✓ Siem Reap  AQI=14  PM2.5=6.4
#   ✓ Battambang  AQI=25  PM2.5=17.3
#   ✓ Kampot  AQI=21  PM2.5=15.3
#   ✓ Sihanoukville  AQI=16  PM2.5=13.6
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 525
#   Waiting 60s...
#
# [20260613_034638] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=31.0
#   ✓ Siem Reap  AQI=14  PM2.5=6.4
#   ✓ Battambang  AQI=25  PM2.5=17.3
#   ✓ Kampot  AQI=21  PM2.5=15.3
#   ✓ Sihanoukville  AQI=16  PM2.5=13.6
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 530
#   Waiting 60s...
#
# [20260613_034742] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=31.0
#   ✓ Siem Reap  AQI=14  PM2.5=6.4
#   ✓ Battambang  AQI=25  PM2.5=17.3
#   ✓ Kampot  AQI=21  PM2.5=15.3
#   ✓ Sihanoukville  AQI=16  PM2.5=13.6
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 535
#   Waiting 60s...
#
# [20260613_034846] Fetching data...
#   ✓ Phnom Penh  AQI=61  PM2.5=31.0
#   ✓ Siem Reap  AQI=14  PM2.5=6.4
#   ✓ Battambang  AQI=25  PM2.5=17.3
#   ✓ Kampot  AQI=21  PM2.5=15.3
#   ✓ Sihanoukville  AQI=16  PM2.5=13.6
#   → Appended 5 rows to air_quality_combined.csv
#   → Total rows in file: 540
#   Waiting 60s...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 33
#      30     print(f"  → Total rows in file: {total}")
#      32 print(f"  Waiting {INTERVAL}s...")
# ---> 33 time.sleep(INTERVAL)
#
# KeyboardInterrupt:
